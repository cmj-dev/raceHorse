# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 훈련 세트 준비

# %%
raceHoresInfo = pd.read_csv('raceHorseInfo.csv', index_col=0)

# %%
raceHoresInfo = raceHoresInfo[raceHoresInfo['rcCntY'] > 0]

# %%
print(raceHoresInfo.columns)
raceHoresInfo.head()
# Out:
# Index(['birthday', 'chaksunT', 'faHrName', 'faHrNo', 'hrLastAmt', 'hrName',
#        'hrNo', 'meet', 'moHrName', 'moHrNo', 'name', 'ord1CntT', 'ord1CntY',
#        'ord2CntT', 'ord2CntY', 'ord3CntT', 'ord3CntY', 'owName', 'owNo',
#        'rank', 'rating', 'rcCntT', 'rcCntY', 'sex', 'trName', 'trNo'],
#       dtype='object')
#     birthday  chaksunT  faHrName   faHrNo     hrLastAmt hrName   hrNo  meet  \
# 10  20190504   5600000    아치아치아치  0040056       기타(비코드)  가기만고당  44848    서울
# 16  20200330   8800000       커널존  0038332  20,000천원(경매)   가나드림  46385    서울
# 20  20190419  87000000     올드패션드  0037972  32,000천원(개별)   가나패션  45027    서울
# 41  20170323  69180000  스트라이크어게인  0029419     100천원(개별)   가디스문  40421  부산경남
# 43  20190506  98800000  어플릿익스프레스  0039737   2,000천원(개별)  가디언엔젤  44254  부산경남
#
#     moHrName   moHrNo  ... ord3CntY  owName    owNo  rank  rating  rcCntT  \
# 10  사라토가스플래쉬  0013959  ...        0       -       -     -       0       5
# ...

# %%
raceHoresInfo.drop(list(filter(lambda x : 'CntT' in x or 'Name'in x or 'fa'in x or 'mo' in x or 'ow' in x or 'tr' in x,raceHoresInfo.columns)), axis=1, inplace=True)
# Out:
# /var/folders/13/_d39kvt523z46phlzs257wb40000gn/T/ipykernel_91233/2675087654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raceHoresInfo.drop(list(filter(lambda x : 'CntT' in x or 'Name'in x or 'fa'in x or 'mo' in x or 'ow' in x or 'tr' in x,raceHoresInfo.columns)), axis=1, inplace=True)

# %%
raceHoresInfo['ordCntY'] = raceHoresInfo[['ord1CntY','ord2CntY','ord3CntY']].sum(axis=1)
raceHoresInfo
# Out:
# /var/folders/13/_d39kvt523z46phlzs257wb40000gn/T/ipykernel_91233/3415090825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raceHoresInfo['ordCntY'] = raceHoresInfo[['ord1CntY','ord2CntY','ord3CntY']].sum(axis=1)
#        birthday   chaksunT     hrLastAmt     hrNo  meet name  ord1CntY  \
# 10     20190504    5600000       기타(비코드)    44848    서울   한국         0
# 16     20200330    8800000  20,000천원(경매)    46385    서울   한국         0
# 20     20190419   87000000  32,000천원(개별)    45027    서울   한국         1
# 41     20170323   69180000     100천원(개별)    40421  부산경남   한국         0
# 43     20190506   98800000   2,000천원(개별)    44254  부산경남   한국         2
# ...         ...        ...           ...      ...   ...  ...       ...
# ...

# %%
horseOrdCnt = raceHoresInfo[['ord1CntY','ord2CntY','ord3CntY']]

# %%
horseOrdCnt['Sum'] = horseOrdCnt.sum(axis=1)
# Out:
# /var/folders/13/_d39kvt523z46phlzs257wb40000gn/T/ipykernel_91233/3827098775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   horseOrdCnt['Sum'] = horseOrdCnt.sum(axis=1)
